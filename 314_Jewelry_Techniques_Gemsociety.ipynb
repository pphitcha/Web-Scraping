# %%
import pandas as pd
import bs4
import requests
from bs4 import BeautifulSoup

# %%
i_page = 1
title_list = []
detail_list = []

while i_page <= 34:
    data = requests.get(f'https://www.gemsociety.org/search/Jewelry_Technique/page/{i_page}/')
    data.encoding = 'utf8'
    soup = bs4.BeautifulSoup(data.text)
    for item in soup.find_all('div', class_='col-md-4'):
        title_list.append(item.find('h5').find('a').text.strip())
        detail_list.append(item.find('div', class_='article-preview__excerpt').text.strip())
        
    print('Complete page number: ',i_page)
    i_page += 1
# Out:
# Complete page number:  1
# Complete page number:  2
# Complete page number:  3
# Complete page number:  4
# Complete page number:  5
# Complete page number:  6
# Complete page number:  7
# Complete page number:  8
# Complete page number:  9
# Complete page number:  10
# Complete page number:  11
# Complete page number:  12
# Complete page number:  13
# Complete page number:  14
# Complete page number:  15
# Complete page number:  16
# Complete page number:  17
# Complete page number:  18
# Complete page number:  19
# Complete page number:  20
# Complete page number:  21
# Complete page number:  22
# Complete page number:  23
# Complete page number:  24
# Complete page number:  25
# Complete page number:  26
# Complete page number:  27
# Complete page number:  28
# Complete page number:  29
# Complete page number:  30
# Complete page number:  31
# Complete page number:  32
# Complete page number:  33
# Complete page number:  34

# %%
soup = BeautifulSoup(data.text, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>
#                             You searched for Jewelry_Technique - Page 34 of 34 - International Gem Society
#                     </title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <script>
#     window.dataLayer = window.dataLayer || [];
#     dataLayer.push({
#         'user_loginstatus': 'anonymous',
#         'event': 'user_data'
#     });
# </script>
# <!-- This site is optimized with the Yoast SEO plugin v19.10 - https://yoast.com/wordpress/plugins/seo/ -->
# <meta content="noindex, follow" name="robots">
# <meta content="en_US" property="og:locale">
# <meta content="article" property="og:type"/>
# <meta content="You searched for Jewelry_Technique - Page 34 of 34 - International Gem Society" property="og:title"/>
# ...

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.DataFrame([title_list,detail_list]).transpose()
df.columns = ['title','detail']
df
# Out:
#                                                                                                                   title  \
# 0                                                            The Ultimate Guide to the Best Jewelry Insurance Companies
# 1                                                                        Jewelry Metals 101: Gold, Silver, and Platinum
# 2                                                                                                        Jewelry Design
# 3                                                                                   A Guide to Antique Georgian Jewelry
# 4                                                                                       A Guide to Belle Époque Jewelry
# 5                                                            Report Card for the Best Engagement Ring Insurance in 2022
# 6                                                                    A Guide to Early Victorian Romantic Period Jewelry
# ...

# %%
df1 =  df.replace({'\“':'\"','\”':'\"','\’':'\'','…':'',' – ':'-','\©':' ','é':'e',' — ':'-','[^\x00-\x7F]+':''}, regex = True)
df1
# Out:
#                                                                                                                   title  \
# 0                                                            The Ultimate Guide to the Best Jewelry Insurance Companies
# 1                                                                        Jewelry Metals 101: Gold, Silver, and Platinum
# 2                                                                                                        Jewelry Design
# 3                                                                                   A Guide to Antique Georgian Jewelry
# 4                                                                                        A Guide to Belle poque Jewelry
# 5                                                            Report Card for the Best Engagement Ring Insurance in 2022
# 6                                                                    A Guide to Early Victorian Romantic Period Jewelry
# ...

# %%
df1.to_csv(r'C:\Users\DELL\Desktop\techniques_2.csv')
