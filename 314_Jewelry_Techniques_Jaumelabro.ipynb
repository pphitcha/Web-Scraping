# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = "https://www.jaumelabro.com/?s=jewelry+techniques"

# %%
res = requests.get(url)
res.encoding = 'utf8'
print(res)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(res.text, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US" prefix="og: https://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <title>Search | Jaume Labro</title>
# <meta content="follow, noindex" name="robots">
# <meta content="en_US" property="og:locale">
# <meta content="article" property="og:type"/>
# <meta content="Search | Jaume Labro" property="og:title"/>
# <meta content="https://www.jaumelabro.com/search/jewelry+techniques/" property="og:url"/>
# <meta content="Jaume Labro" property="og:site_name"/>
# <meta content="https://www.facebook.com/jaumelabro1" property="article:publisher"/>
# <meta content="https://www.jaumelabro.com/wp-content/uploads/2021/11/mokume-gane-fine-jewelry-by-jaume-labro-award-winner-designer.jpg" property="og:image"/>
# ...

# %%
pd.set_option('display.max_colwidth', None)

# %%
title_list = []
detail_list = []

for item in soup.find_all('article'):
        title_list.append(item.find('h2').find('a').text.strip())
        detail_list.append(item.find('p').text.strip())

# %%
df = pd.DataFrame([title_list,detail_list]).transpose()
df.columns = ['title','detail']
df
# Out:
#                                            title  \
# 0         9 Incredible Jewelry Making Techniques
# 1            Mokume Gane Bespoke Jewelry Designs
# 2          Mokume Gane vs Damascus Steel Jewelry
# 3   Ancient Metalworking Used in Today’s Jewelry
# 4       Why Custom Ethical Jewelry Is the Future
# 5            Sitting Down with Jose Luis Jewelry
# 6           Apollo Wide Mokume Gane Wedding Band
# 7      The Traditional Japanese Art of Shibuichi
# 8       Zephyr & Horus Sustainable Wedding Bands
# 9                                Our Mokume Gane
# 10                            Lifetime Guarantee
# 11                          What Is Mokume Gane?
# 12                             About Jaume Labro
# 13  How Many Different Colors of Gold Are There?
# 14       The Time-Honored History of Mokume Gane
# 15   The History of Engagement and Wedding Rings
#
# ...

# %%
df1 =  df.replace({'\’':'\'','\[…\]':'',' – ':'-','[^\x00-\x7F]+':''}, regex = True)
df1
# Out:
#                                            title  \
# 0         9 Incredible Jewelry Making Techniques
# 1            Mokume Gane Bespoke Jewelry Designs
# 2          Mokume Gane vs Damascus Steel Jewelry
# 3   Ancient Metalworking Used in Today's Jewelry
# 4       Why Custom Ethical Jewelry Is the Future
# 5            Sitting Down with Jose Luis Jewelry
# 6           Apollo Wide Mokume Gane Wedding Band
# 7      The Traditional Japanese Art of Shibuichi
# 8       Zephyr & Horus Sustainable Wedding Bands
# 9                                Our Mokume Gane
# 10                            Lifetime Guarantee
# 11                          What Is Mokume Gane?
# 12                             About Jaume Labro
# 13  How Many Different Colors of Gold Are There?
# 14       The Time-Honored History of Mokume Gane
# 15   The History of Engagement and Wedding Rings
#
# ...

# %%
df1.to_csv(r'C:\Users\DELL\Desktop\techniques_13.csv')
